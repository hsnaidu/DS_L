# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Importing Libraries

# %% [markdown]
# DATETIMEINDEX &
# RESAMPLING

# %%
df = pd.read_csv("C:\\Users\\harip\\Desktop\\projects\\data\\aapl.csv")
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0   7-Jul-17  142.90  144.75  142.90  144.18  19201712
# 1   6-Jul-17  143.02  143.50  142.41  142.73  24128782
# 2   5-Jul-17  143.69  144.79  142.72  144.09  21569557
# 3   3-Jul-17  144.88  145.30  143.10  143.50  14277848
# 4  30-Jun-17  144.45  144.96  143.78  144.02  23024107

# %%
df = pd.read_csv("C:\\Users\\harip\\Desktop\\projects\\data\\aapl.csv",parse_dates=["Date"] , index_col=["Date"])
# NOTE converting the date formate & setting the index_col as Date
df.head()
# Out:
# C:\Users\harip\AppData\Local\Temp\ipykernel_18328\1157518078.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("C:\\Users\\harip\\Desktop\\projects\\data\\aapl.csv",parse_dates=["Date"] , index_col=["Date"])
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.loc['2017-07-07']
# Out:
# Open           142.90
# High           144.75
# Low            142.90
# Close          144.18
# Volume    19201712.00
# Name: 2017-07-07 00:00:00, dtype: float64

# %%
df.iloc[0:10].mean() # take the mean value of the values
# Out:
# Open      1.445450e+02
# High      1.456140e+02
# Low       1.434460e+02
# Close     1.443860e+02
# Volume    2.416774e+07
# dtype: float64

# %% [markdown]
# RESAMPLING

# %%
# Retrive only monthly data
# %matplotlib inline
df.Close.resample('M').mean().plot() # shows the monthly avg values 
df.Close.resample('W').mean().plot() # shows the weakly avg values 
df.Close.resample('D').mean().plot() # shows the daily avg values 
df.Close.resample('Q').mean().plot() # shows the Quaterly avg values 
# NOTE CHECK PANDAS ORG FOR MORE RESAMPLE METHODS
# Out:
# C:\Users\harip\AppData\Local\Temp\ipykernel_18328\1613881826.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample('M').mean().plot() # shows the monthly avg values
# C:\Users\harip\AppData\Local\Temp\ipykernel_18328\1613881826.py:6: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean().plot() # shows the Quaterly avg values
# <Axes: xlabel='Date'>

# %%
df.Close.resample('Q').mean().plot(kind = "bar")
# Out:
# C:\Users\harip\AppData\Local\Temp\ipykernel_18328\2086901434.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean().plot(kind = "bar")
# <Axes: xlabel='Date'>

# %%
# NOTE we can even plot for a col
df.Close.plot()
# Out:
# <Axes: xlabel='Date'>
